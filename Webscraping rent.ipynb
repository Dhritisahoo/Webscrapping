# %% [markdown]
# # I have webscraped the front page of “Trulia” Housing and "Appartments.com" and get a distribution of low/high end housing costs

# %%
# Import Packages
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# We talk about user agents later so run and ignore
user_agent_list = ["Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246" 
,"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.111 Safari/537.36 "
,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9 "
,"Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:15.0) Gecko/20100101 Firefox/15.0.1" 
,"Mozilla/5.0 (X11; CrOS x86_64 8172.45.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.64 Safari/537.36"] 

headers = {
    'User-Agent': user_agent_list[3]}

# %%
# Do your Request
URL = "https://www.trulia.com/for_rent/New_York,NY/"
page = requests.get(URL, headers = headers)

# %%
# Response of request object
print(page)
# Out:
# <Response [200]>

# %%
# The Type of the response object
print(type(page))
# Out:
# <class 'requests.models.Response'>

# %%
# Convert to the soup object
soup = BeautifulSoup(page.content, "html.parser")

# %%
# Type of Soup object
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
# Make the HTML Pretty
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Apartments For Rent in New York, NY - 13,362 Long Term Rentals | Trulia
#   </title>
#   <meta content="Search 13,362 Rental Properties in New York, New York. Explore rentals by neighborhoods, schools, local guides and more on Trulia!" name="description"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0, viewport-fit=cover" name="viewport"/>
#   <meta content="5953837487" property="fb:admins"/>
#   <meta content="183577541666001" property="fb:app_id"/>
#   <meta content="Trulia" property="application-name"/>
#   <meta content="https://www.trulia.com" property="msapplication-starturl"/>
#   <meta content="Trulia: Real Estate Search" property="msapplication-tooltip"/>
#   <meta content="/browserconfig.xml" property="msapplication-config"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="Trulia Real Estate Search" property="og:site_name"/>
#   <meta content="website" property="og:type"/>
#   <meta content="@trulia" property="twitter:site"/>
#   <meta content="yes" property="mobile-web-app-capable"/>
#   <meta content="#ffffff" property="theme-color"/>
#   <meta content="yes" property="apple-mobile-web-app-capable"/>
#   <link href="https://assets.adobedtm.com" rel="preconnect"/>
#   <link href="https://maps.googleapis.com" rel="preconnect"/>
#   <link href="https://collector-PXYO6YjwLb.px-cloud.net" rel="preconnect"/>
#   <link href="https://assets.adobedtm.com" rel="dns-prefetch"/>
#   <link href="https://maps.googleapis.com" rel="dns-prefetch"/>
#   <link href="https://collector-PXYO6YjwLb.px-cloud.net" rel="dns-prefetch"/>
#   <link href="/manifest" rel="manifest"/>
#   <link href="//www.trulia.com/images/icons/app/app-icon-120.png" rel="apple-touch-icon-precomposed"/>
#   <link href="//www.trulia.com/images/icons/app/app-icon-144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#   <link href="//www.trulia.com/images/icons/app/app-icon-152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
#   <link href="//www.trulia.com/images/icons/app/app-icon-180.png" rel="apple-touch-icon-precomposed" sizes="180x180"/>
#   <link href="//www.trulia.com/images/icons/app/app-icon-196.png" rel="shortcut icon" sizes="196x196"/>
#   <link href="//www.trulia.com/images/icons/favicon-rebrand-128.png" rel="icon" sizes="120x120"/>
#   <link href="//www.trulia.com/images/icons/favicon-rebrand-196.png" rel="icon" sizes="196x196"/>
#   <link href="//www.trulia.com/images/icons/app/app-icon-228.png" rel="icon" sizes="228x228"/>
#   <link color="#00ADBB" href="//www.trulia.com/images/icons/mask-icon.svg" rel="mask-icon"/>
#   <link as="image" href="https://www.trulia.com/pictures/thumbs_4/zillowstatic/fp/00ca20c0f040f67e66bfc6738275e5fa-full.jpg" rel="preload"/>
#   <link as="image" href="https://www.trulia.com/images/backgrounds/map-gray-background.png" rel="preload"/>
#   <link href="android-app://com.trulia.android/https/www.trulia.com/for_rent/New_York,NY/" rel="alternate"/>
#   <link href="ios-app://288487321/https/www.trulia.com/for_rent/New_York,NY/" rel="alternate"/>
#   <link href="https://www.trulia.com/for_rent/New_York,NY/" rel="canonical"/>
#   <meta content="INDEX, FOLLOW" name="robots"/>
#   <meta content="https://www.trulia.com/for_rent/New_York,NY/" property="og:url"/>
#   <meta content="Search 13,362 Rental Properties in New York, New York. Explore rentals by neighborhoods, schools, local guides and more on Trulia!" property="og:description"/>
#   <meta content="Apartments For Rent in New York, NY - 13,362 Long Term Rentals | Trulia" property="og:title"/>
#   <meta content="https://www.trulia.com/images/logos/standardized/v4/logo-with-icon-200x200.png" property="og:image"/>
#   <meta content="200" property="og:image:width"/>
#   <meta content="200" property="og:image:height"/>
#   <meta content="45" name="next-head-count"/>
#   <style data-styled="" data-styled-version="5.3.6">
#    .caedLv{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g1[id="MediaBlock__MediaContainer-sc-ad2f5bfc-0"]{content:"caedLv,"}/*!sc*/
# .jTGvwb{margin:0 4px;}/*!sc*/
# .jTGvwb:last-child{margin-right:0;}/*!sc*/
# .jTGvwb:first-child{margin-left:0;}/*!sc*/
# .cwAjkT{margin:0 8px;}/*!sc*/
# .cwAjkT:last-child{margin-right:0;}/*!sc*/
# .cwAjkT:first-child{margin-left:0;}/*!sc*/
# .gUzFjK{-webkit-flex:1 1 0px;-ms-flex:1 1 0px;flex:1 1 0px;width:100%;margin:0;}/*!sc*/
# .gUzFjK:last-child{margin-right:0;}/*!sc*/
# .gUzFjK:first-child{margin-left:0;}/*!sc*/
# .ikaifl{margin:0 2px;}/*!sc*/
# .ikaifl:last-child{margin-right:0;}/*!sc*/
# .ikaifl:first-child{margin-left:0;}/*!sc*/
# .fRRmMa{-webkit-flex:1 1 0px;-ms-flex:1 1 0px;flex:1 1 0px;width:100%;margin:0 8px;}/*!sc*/
# .fRRmMa:last-child{margin-right:0;}/*!sc*/
# .fRRmMa:first-child{margin-left:0;}/*!sc*/
# .iIUpgh{-webkit-flex:1 1 0px;-ms-flex:1 1 0px;flex:1 1 0px;width:100%;margin:0 8px;overflow:hidden;}/*!sc*/
# .iIUpgh:last-child{margin-right:0;}/*!sc*/
# .iIUpgh:first-child{margin-left:0;}/*!sc*/
# .gSCYuI{margin:0 8px;overflow:hidden;}/*!sc*/
# .gSCYuI:last-child{margin-right:0;}/*!sc*/
# .gSCYuI:first-child{margin-left:0;}/*!sc*/
# .jykePe{margin:0 2px;overflow:hidden;}/*!sc*/
# .jykePe:last-child{margin-right:0;}/*!sc*/
# .jykePe:first-child{margin-left:0;}/*!sc*/
# data-styled.g2[id="MediaBlock__MediaContent-sc-ad2f5bfc-1"]{content:"jTGvwb,cwAjkT,gUzFjK,ikaifl,fRRmMa,iIUpgh,gSCYuI,jykePe,"}/*!sc*/
# .dbBNo{width:16px !important;height:16px !important;display:inline-block;font-size:0;}/*!sc*/
# .dbBNo .svg{width:16px;}/*!sc*/
# .dbBNo .svg{height:16px;}/*!sc*/
# .dbBNo path{fill:rgb(107,119,128);}/*!sc*/
# .githEe{width:24px !important;height:24px !important;display:inline-block;font-size:0;}/*!sc*/
# .githEe .svg{width:24px;}/*!sc*/
# .githEe .svg{height:24px;}/*!sc*/
# .githEe path{fill:rgb(255,255,255);}/*!sc*/
# .cLfwaV{width:24px !important;height:24px !important;display:inline-block;font-size:0;}/*!sc*/
# .cLfwaV .svg{width:24px;}/*!sc*/
# .cLfwaV .svg{height:24px;}/*!sc*/
# .cLfwaV path{fill:rgb(0,120,130);}/*!sc*/
# .emjeJJ{width:24px !important;height:24px !important;display:inline-block;font-size:0;}/*!sc*/
# .emjeJJ .svg{width:24px;}/*!sc*/
# .emjeJJ .svg{height:24px;}/*!sc*/
# .emjeJJ path{fill:rgb(59,65,68);}/*!sc*/
# .bEcLEh{width:16px !important;height:24px !important;display:inline-block;font-size:0;}/*!sc*/
# .bEcLEh .svg{width:16px;}/*!sc*/
# .bEcLEh .svg{height:24px;}/*!sc*/
# .bEcLEh path{fill:rgb(0,120,130);}/*!sc*/
# .lawCep{width:16px !important;height:24px !important;display:inline-block;font-size:0;}/*!sc*/
# .lawCep .svg{width:16px;}/*!sc*/
# .lawCep .svg{height:24px;}/*!sc*/
# .lawCep path{fill:rgb(59,65,68);}/*!sc*/
# .dMGKtZ{width:20px !important;height:20px !important;display:inline-block;font-size:0;}/*!sc*/
# .dMGKtZ .svg{width:20px;}/*!sc*/
# .dMGKtZ .svg{height:20px;}/*!sc*/
# .dMGKtZ path{fill:rgb(0,120,130);}/*!sc*/
# .gZZJMh{width:16px !important;height:16px !important;display:inline-block;font-size:0;}/*!sc*/
# .gZZJMh .svg{width:16px;}/*!sc*/
# .gZZJMh .svg{height:16px;}/*!sc*/
# .gZZJMh path{fill:rgb(0,120,130);}/*!sc*/
# data-styled.g3[id="getUiSvgContainer__SvgContainer-sc-3c9612d7-0"]{content:"dbBNo,githEe,cLfwaV,emjeJJ,bEcLEh,lawCep,dMGKtZ,gZZJMh,"}/*!sc*/
# .cjJBIb{display:none;}/*!sc*/
# .bjkomQ{display:block;}/*!sc*/
# .kOLrPk{display:block;border-style:solid !important;border-color:rgb(205,209,212);border-width:0 0 1px 0;}/*!sc*/
# .gCrYQO{display:block;}/*!sc*/
# @media (min-width:376px){.gCrYQO{display:block;}}/*!sc*/
# @media (min-width:570px){.gCrYQO{display:block;}}/*!sc*/
# @media (min-width:768px){.gCrYQO{display:none;}}/*!sc*/
# @media (min-width:993px){.gCrYQO{display:none;}}/*!sc*/
# .gdQUCa{display:none;}/*!sc*/
# @media (min-width:376px){.gdQUCa{display:none;}}/*!sc*/
# @media (min-width:570px){.gdQUCa{display:none;}}/*!sc*/
# @media (min-width:768px){.gdQUCa{display:block;}}/*!sc*/
# @media (min-width:993px){.gdQUCa{display:none;}}/*!sc*/
# .bcJHmW{display:none;}/*!sc*/
# @media (min-width:376px){.bcJHmW{display:none;}}/*!sc*/
# @media (min-width:570px){.bcJHmW{display:none;}}/*!sc*/
# @media (min-width:768px){.bcJHmW{display:none;}}/*!sc*/
# @media (min-width:993px){.bcJHmW{display:block;}}/*!sc*/
# .YZyOG{display:inline-block;width:100%;display:inline-block;}/*!sc*/
# .iEKIkt{width:100%;display:block;}/*!sc*/
# @media (min-width:376px){.iEKIkt{display:block;}}/*!sc*/
# @media (min-width:570px){.iEKIkt{display:block;}}/*!sc*/
# @media (min-width:768px){.iEKIkt{display:none;}}/*!sc*/
# data-styled.g4[id="Box__BoxElement-sc-9529e829-0"]{content:"cjJBIb,bjkomQ,kOLrPk,gCrYQO,gdQUCa,bcJHmW,YZyOG,iEKIkt,"}/*!sc*/
# .bSUoRr{cursor:pointer;display:block;-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;outline:none;}/*!sc*/
# .bSUoRr[role='button']:active{outline:none;box-shadow:0 0 0 1px rgb(107,119,128);}/*!sc*/
# .bSUoRr:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# .cpuvdb{cursor:pointer;display:inline;-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;outline:none;}/*!sc*/
# .cpuvdb[role='button']:active{outline:none;box-shadow:0 0 0 1px rgb(107,119,128);}/*!sc*/
# .cpuvdb:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# .jTslXf{cursor:pointer;display:inline-block;-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;outline:none;}/*!sc*/
# .jTslXf[role='button']:active{outline:none;box-shadow:0 0 0 1px rgb(107,119,128);}/*!sc*/
# .jTslXf:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# data-styled.g5[id="BoxButton-sc-155631a2-0"]{content:"bSUoRr,cpuvdb,jTslXf,"}/*!sc*/
# .cVaxpe{font-weight:bold;}/*!sc*/
# .fxZmah{font-size:16px;line-height:1.5;}/*!sc*/
# .fxZmah .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:24px;width:24px;}/*!sc*/
# .eKgmWm{color:rgb(59,65,68);font-size:16px;line-height:1.5;}/*!sc*/
# .eKgmWm .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:24px;width:24px;}/*!sc*/
# .gCtNDd{font-size:14px;line-height:1.43;}/*!sc*/
# .gCtNDd .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:20.02px;width:20.02px;}/*!sc*/
# data-styled.g7[id="Text__TextBase-sc-27a633b1-0"]{content:"cVaxpe,fxZmah,eKgmWm,gCtNDd,bOnOwI,"}/*!sc*/
# .diAvex{color:rgb(0,120,130);}/*!sc*/
# .ewcDjf{font-weight:bold;font-size:20px;line-height:1.2;}/*!sc*/
# .ewcDjf .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:24px;width:24px;}/*!sc*/
# .cYrgQP{font-size:16px;line-height:1.5;}/*!sc*/
# .cYrgQP .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:24px;width:24px;}/*!sc*/
# .dzGcIc{color:rgb(107,119,128);font-size:10px;line-height:1.6;}/*!sc*/
# .dzGcIc .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:16px;width:16px;}/*!sc*/
# .erIIjN{font-weight:bold;font-size:14px;line-height:1.43;}/*!sc*/
# .erIIjN .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:20.02px;width:20.02px;}/*!sc*/
# .eBkEfA{color:rgb(107,119,128);font-size:12px;line-height:1.33;}/*!sc*/
# .eBkEfA .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:15.96px;width:15.96px;}/*!sc*/
# .cKPFhe{font-weight:bold;font-size:14px;line-height:1.43;}/*!sc*/
# @media (min-width:376px){.cKPFhe{font-size:14px;}}/*!sc*/
# @media (min-width:570px){.cKPFhe{font-size:14px;}}/*!sc*/
# @media (min-width:768px){.cKPFhe{font-size:16px;}}/*!sc*/
# @media (min-width:376px){.cKPFhe{line-height:1.43;}}/*!sc*/
# @media (min-width:570px){.cKPFhe{line-height:1.43;}}/*!sc*/
# @media (min-width:768px){.cKPFhe{line-height:1.5;}}/*!sc*/
# .cKPFhe .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:20.02px;width:20.02px;}/*!sc*/
# @media (min-width:376px){.cKPFhe .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:20.02px;}}/*!sc*/
# @media (min-width:570px){.cKPFhe .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:20.02px;}}/*!sc*/
# @media (min-width:768px){.cKPFhe .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:24px;}}/*!sc*/
# @media (min-width:376px){.cKPFhe .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{width:20.02px;}}/*!sc*/
# @media (min-width:570px){.cKPFhe .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{width:20.02px;}}/*!sc*/
# @media (min-width:768px){.cKPFhe .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{width:24px;}}/*!sc*/
# .bzzQyw{font-weight:bold;}/*!sc*/
# data-styled.g8[id="Text__TextBase-sc-27a633b1-0-div"]{content:"cKvYni,diAvex,ewcDjf,cYrgQP,dzGcIc,erIIjN,eBkEfA,cKPFhe,bzzQyw,"}/*!sc*/
# .keSfom{white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# data-styled.g9[id="Text__TextContainerBase-sc-27a633b1-1"]{content:"gtvmjT,keSfom,"}/*!sc*/
# .fACcjp{padding:8px 16px 8px 16px;}/*!sc*/
# .kTAvYR{padding:0 8px 0 0;}/*!sc*/
# .kaWoYH{padding:0 0 0 2px;}/*!sc*/
# .essoCv{padding:4px 2px 0 0;}/*!sc*/
# .kIlYiJ{padding:8px 0 0 0;}/*!sc*/
# .qoyrV{padding:0 8px 0 8px;}/*!sc*/
# .kIlYiP{padding:2px 0 0 0;}/*!sc*/
# .kTAAQh{padding:0 4px 0 0;}/*!sc*/
# .dxhhkR{padding:24px 8px 24px 8px;}/*!sc*/
# .eiYdwl{padding:8px;}/*!sc*/
# .jBBgWA{padding:0 0 32px 0;}/*!sc*/
# .fXlXF{padding:16px 0 16px 0;}/*!sc*/
# data-styled.g10[id="Padding-sc-bf66b591-0"]{content:"fACcjp,kTAvYR,kaWoYH,essoCv,kIlYiJ,qoyrV,kIlYiP,kTAAQh,dxhhkR,eiYdwl,jBBgWA,fXlXF,"}/*!sc*/
# .lehSFb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}/*!sc*/
# data-styled.g14[id="FlexContainers__Columns-sc-a0824eb3-2"]{content:"lehSFb,"}/*!sc*/
# .cNJlGF{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;-webkit-text-decoration:none;text-decoration:none;font-size:16px;line-height:1.5;padding:8px 16px;outline:none;}/*!sc*/
# .cNJlGF path{-webkit-transition:fill 0.1s;transition:fill 0.1s;}/*!sc*/
# .cNJlGF .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:24px;width:24px;}/*!sc*/
# .cNJlGF::-moz-focus-inner{border:0;}/*!sc*/
# .cNJlGF[disabled]{cursor:none;pointer-events:none;}/*!sc*/
# .cNJlGF:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# .gkAsVK{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;-webkit-text-decoration:none;text-decoration:none;font-size:14px;line-height:1.43;padding:8px;outline:none;}/*!sc*/
# .gkAsVK path{-webkit-transition:fill 0.1s;transition:fill 0.1s;}/*!sc*/
# .gkAsVK .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:20.02px;width:20.02px;}/*!sc*/
# .gkAsVK::-moz-focus-inner{border:0;}/*!sc*/
# .gkAsVK[disabled]{cursor:none;pointer-events:none;}/*!sc*/
# .gkAsVK:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# .blaxzu{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;-webkit-text-decoration:none;text-decoration:none;font-size:14px;line-height:1.43;padding:8px;width:100%;outline:none;}/*!sc*/
# .blaxzu path{-webkit-transition:fill 0.1s;transition:fill 0.1s;}/*!sc*/
# .blaxzu .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:20.02px;width:20.02px;}/*!sc*/
# .blaxzu::-moz-focus-inner{border:0;}/*!sc*/
# .blaxzu[disabled]{cursor:none;pointer-events:none;}/*!sc*/
# .blaxzu:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# data-styled.g22[id="ButtonBase-sc-ca7e2680-0"]{content:"cNJlGF,gkAsVK,blaxzu,"}/*!sc*/
# .fZURYe{color:rgb(255,255,255);background-color:rgb(0,120,130);border-color:transparent;box-shadow:0px 8px 20px -15px rgba(59,65,68,0.7);margin-bottom:16px;outline:none;}/*!sc*/
# .fZURYe .getUiSvgContainer__SvgContainer-sc-3c9612d7-0 path{fill:rgb(255,255,255);}/*!sc*/
# .fZURYe[class~='hover'],.fZURYe:hover{color:rgb(0,120,130);background-color:rgb(255,255,255);border-color:rgb(0,120,130);}/*!sc*/
# .fZURYe[class~='hover'] .getUiSvgContainer__SvgContainer-sc-3c9612d7-0 path,.fZURYe:hover .getUiSvgContainer__SvgContainer-sc-3c9612d7-0 path{fill:rgb(0,120,130);}/*!sc*/
# .fZURYe[class~='focus'],.fZURYe:focus{color:rgb(0,120,130);background-color:rgb(224,247,248);border-color:rgb(0,120,130);}/*!sc*/
# .fZURYe[class~='focus'] .getUiSvgContainer__SvgContainer-sc-3c9612d7-0 path,.fZURYe:focus .getUiSvgContainer__SvgContainer-sc-3c9612d7-0 path{fill:rgb(0,120,130);}/*!sc*/
# .fZURYe[class~='active'],.fZURYe:active{color:rgb(255,255,255);background-color:rgb(0,120,130);border-color:transparent;box-shadow:none;}/*!sc*/
# .fZURYe[class~='active'] .getUiSvgContainer__SvgContainer-sc-3c9612d7-0 path,.fZURYe:active .getUiSvgContainer__SvgContainer-sc-3c9612d7-0 path{fill:rgb(255,255,255);}/*!sc*/
# .fZURYe[disabled]{color:rgb(205,209,212);background-color:rgb(245,246,247);border-color:rgb(205,209,212);box-shadow:none;}/*!sc*/
# .fZURYe[disabled] .getUiSvgContainer__SvgContainer-sc-3c9612d7-0 path{fill:rgb(205,209,212);}/*!sc*/
# .fZURYe:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# data-styled.g23[id="PrimaryButton-sc-d1dba674-0"]{content:"fZURYe,"}/*!sc*/
# .hbfUXF{line-height:1;color:inherit;}/*!sc*/
# .hbfUXF:hover,.hbfUXF:focus{color:rgb(0,120,130);}/*!sc*/
# .hbfUXF:hover path,.hbfUXF:focus path{fill:rgb(0,120,130);}/*!sc*/
# .IQOBW{line-height:1;color:inherit;}/*!sc*/
# data-styled.g30[id="UiButton-sc-457c87e0-0"]{content:"hbfUXF,IQOBW,"}/*!sc*/
# .dYjNTy{color:rgb(59,65,68);background-color:rgb(255,255,255);border-color:rgb(205,209,212);}/*!sc*/
# .dYjNTy:hover,.dYjNTy[class~='hover']{color:rgb(59,65,68);background-color:rgb(232,233,234);border-color:transparent;}/*!sc*/
# .dYjNTy[class~='focus'],.dYjNTy:focus{color:rgb(59,65,68);background-color:rgb(255,255,255);border-color:rgb(107,119,128);outline:none;}/*!sc*/
# .dYjNTy[class~='focus']:focus-visible,.dYjNTy:focus:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# .dYjNTy[class~='active'],.dYjNTy:active{color:rgb(255,255,255);background-color:rgb(107,119,128);border-color:transparent;}/*!sc*/
# .dYjNTy[class~='active'] .getUiSvgContainer__SvgContainer-sc-3c9612d7-0 path,.dYjNTy:active .getUiSvgContainer__SvgContainer-sc-3c9612d7-0 path{fill:rgb(255,255,255);}/*!sc*/
# .dYjNTy[disabled]{color:rgb(205,209,212);background-color:rgb(245,246,247);border-color:rgb(205,209,212);}/*!sc*/
# .dYjNTy[disabled] .getUiSvgContainer__SvgContainer-sc-3c9612d7-0 path{fill:rgb(205,209,212);}/*!sc*/
# data-styled.g33[id="Button-sc-7eadec1-0"]{content:"dYjNTy,"}/*!sc*/
# @font-face{font-family:"TruliaSans";src: url("https://www.trulia.com/images/fonts/TruliaSans_20190627/TruliaSansWeb-Regular.woff2") format("woff2"), url("https://www.trulia.com/images/fonts/TruliaSans_20190627/TruliaSansWeb-Regular.woff") format("woff");font-weight:400;font-style:normal;font-display:swap;}/*!sc*/
# @font-face{font-family:"TruliaSans";src: url("https://www.trulia.com/images/fonts/TruliaSans_20190627/TruliaSansWeb-Bold.woff2") format("woff2"), url("https://www.trulia.com/images/fonts/TruliaSans_20190627/TruliaSansWeb-Bold.woff") format("woff");font-weight:600;font-style:normal;font-display:swap;}/*!sc*/
# @font-face{font-family:"Trulia-Fallback";size-adjust:102%;ascent-override:90%;-webkit-descent-override:30%;descent-override:30%;src:local("Arial");}/*!sc*/
# html,body{margin:0;padding:0;font-family:'TruliaSans',Trulia-Fallback,sans-serif;color:rgb(59,65,68);background-color:rgb(255,255,255);font-size:16px;line-height:1.5;-webkit-letter-spacing:-.1px;-moz-letter-spacing:-.1px;-ms-letter-spacing:-.1px;letter-spacing:-.1px;}/*!sc*/
# html .getUiSvgContainer__SvgContainer-sc-3c9612d7-0,body .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:24px;width:24px;}/*!sc*/
# *{box-sizing:border-box;}/*!sc*/
# ::-moz-focus-inner{border:0;}/*!sc*/
# a{color:rgb(0,120,130);-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;outline:none;}/*!sc*/
# a:hover{color:rgb(0,69,75);}/*!sc*/
# a:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# ul{margin:0;padding:0;list-style:none;}/*!sc*/
# h1,h2,h3,h4,h5,h6{margin-top:0;margin-bottom:8px;}/*!sc*/
# h1{font-size:28px;}/*!sc*/
# h2{font-size:24px;}/*!sc*/
# h3{font-size:20px;}/*!sc*/
# h4{font-size:16px;}/*!sc*/
# h5{font-size:14px;}/*!sc*/
# h6{font-size:12px;}/*!sc*/
# input,button,textarea{font-family:'TruliaSans',Trulia-Fallback,sans-serif;font-size:16px;line-height:1.5;}/*!sc*/
# input .getUiSvgContainer__SvgContainer-sc-3c9612d7-0,button .getUiSvgContainer__SvgContainer-sc-3c9612d7-0,textarea .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:24px;width:24px;}/*!sc*/
# .modalActive{overflow:hidden !important;max-height:100%;}/*!sc*/
# .focus-visible,.focus-visible:focus{-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;outline:none;box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# data-styled.g42[id="sc-global-zWsGC1"]{content:"sc-global-zWsGC1,"}/*!sc*/
# .fhkpkF{width:100%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# @media (min-width:376px){.fhkpkF{width:100%;}}/*!sc*/
# @media (min-width:570px){.fhkpkF{width:100%;}}/*!sc*/
# @media (min-width:768px){.fhkpkF{width:100%;}}/*!sc*/
# @media (min-width:993px){.fhkpkF{width:50%;}}/*!sc*/
# .cSbzqm{display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# data-styled.g44[id="Grid__CellBox-sc-6b10767f-0"]{content:"fhkpkF,cSbzqm,"}/*!sc*/
# .cHqTDw{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-left:-8px;margin-right:-8px;margin-top:-16px;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# .cHqTDw > .Grid__CellBox-sc-6b10767f-0{border-style:solid;border-color:transparent;border-width:16px 8px 0px 8px;}/*!sc*/
# .fMtReY{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-left:-8px;margin-right:-8px;margin-top:-16px;-webkit-flex-wrap:nowrap;-ms-flex-wrap:nowrap;flex-wrap:nowrap;overflow-x:auto;-webkit-overflow-scrolling:touch;}/*!sc*/
# .fMtReY > .Grid__CellBox-sc-6b10767f-0{border-style:solid;border-color:transparent;border-width:16px 8px 0px 8px;}/*!sc*/
# data-styled.g45[id="Grid__GridContainer-sc-6b10767f-1"]{content:"cHqTDw,fMtReY,"}/*!sc*/
# .gGipxX{object-fit:cover;width:100%;height:100%;}/*!sc*/
# .dToGWc{width:20px;height:20px;}/*!sc*/
# .cvQlys{width:128px;height:128px;}/*!sc*/
# data-styled.g47[id="Image__ImageContainer-sc-776ebfb1-0"]{content:"gGipxX,dToGWc,cvQlys,"}/*!sc*/
# .kQnkh{width:70px;height:24px;display:inline-block;line-height:0;}/*!sc*/
# .kQnkh .svg{width:70px;}/*!sc*/
# .kQnkh .svg{height:24px;}/*!sc*/
# data-styled.g49[id="getSvgContainer__SvgContainer-sc-8b93bed-0"]{content:"kQnkh,"}/*!sc*/
# .hXzyir{height:20px;}/*!sc*/
# .hXzyir .svg{height:20px;}/*!sc*/
# data-styled.g50[id="getSvgContainer__StyledImage-sc-8b93bed-1"]{content:"hXzyir,"}/*!sc*/
# .WqVWB{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .WqVWB:hover{-webkit-text-decoration:underline;text-decoration:underline;color:rgb(0,69,75);}/*!sc*/
# data-styled.g51[id="Anchor__StyledText-sc-fead93c0-0"]{content:"WqVWB,"}/*!sc*/
# .dysGWC{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .dysGWC:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .cgbIeG{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .cgbIeG:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g52[id="Anchor__StyledAnchor-sc-fead93c0-1"]{content:"dysGWC,cgbIeG,"}/*!sc*/
# .jUuqmF{position:absolute;left:-10000px;-webkit-clip:rect(1px 1px 1px 1px);clip:rect(1px 1px 1px 1px);-webkit-clip:rect(1px,1px,1px,1px);clip:rect(1px,1px,1px,1px);padding:0;border:0;height:1px;width:1px;overflow:hidden;}/*!sc*/
# data-styled.g56[id="ScreenReaderContent-sc-b23e9556-0"]{content:"jUuqmF,"}/*!sc*/
# .eOGHOC{background-color:rgb(232,233,234);background-size:300px;background-repeat:no-repeat;background-image:linear-gradient( to right,rgb(232,233,234),rgb(245,246,247),rgb(232,233,234) );-webkit-animation-name:frcLSP;animation-name:frcLSP;-webkit-animation-duration:1.5s;animation-duration:1.5s;-webkit-animation-iteration-count:infinite;animation-iteration-count:infinite;}/*!sc*/
# data-styled.g60[id="Shimmer-sc-20658ef-0"]{content:"eOGHOC,"}/*!sc*/
# .VmeEH{font-size:0;}/*!sc*/
# data-styled.g61[id="TextPlaceholder__TextPlaceholderContainer-sc-504921cd-0"]{content:"VmeEH,"}/*!sc*/
# .gkTkYS{height:20px;height:20px;width:100%;}/*!sc*/
# .fKhrQz{height:20px;height:28px;width:100px;}/*!sc*/
# .kUOGbW{height:20px;height:38px;width:50px;}/*!sc*/
# .dUmDTW{height:20px;height:16px;width:90px;}/*!sc*/
# .dUmDUa{height:20px;height:16px;width:50px;}/*!sc*/
# .dUmDTt{height:20px;height:16px;width:93px;}/*!sc*/
# .eeuxZt{height:20px;height:16px;width:130px;}/*!sc*/
# .eeuxYI{height:20px;height:16px;width:160px;}/*!sc*/
# data-styled.g62[id="TextPlaceholder__TextPlaceholderMark-sc-504921cd-1"]{content:"gkTkYS,fKhrQz,kUOGbW,dUmDTW,dUmDUa,dUmDTt,eeuxZt,eeuxYI,"}/*!sc*/
# .jWUIdd{height:24px;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# .dgypZz{height:31.919999999999998px;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# .cZBPly{height:39.9px;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# data-styled.g63[id="TextPlaceholder-sc-504921cd-2"]{content:"jWUIdd,dgypZz,cZBPly,"}/*!sc*/
# .dNOoIw{color:rgb(59,65,68);background-color:rgb(255,255,255);border-color:transparent;}/*!sc*/
# .dNOoIw .getUiSvgContainer__SvgContainer-sc-3c9612d7-0 path{fill:rgb(59,65,68);}/*!sc*/
# .dNOoIw[class~='hover'],.dNOoIw:hover{color:rgb(255,255,255);background-color:rgb(0,120,130);border-color:transprant;}/*!sc*/
# .dNOoIw[class~='hover'] .getUiSvgContainer__SvgContainer-sc-3c9612d7-0 path,.dNOoIw:hover .getUiSvgContainer__SvgContainer-sc-3c9612d7-0 path{fill:rgb(255,255,255);}/*!sc*/
# .dNOoIw[class~='focus'],.dNOoIw:focus{color:rgb(0,120,130);border-color:rgb(0,120,130);}/*!sc*/
# .dNOoIw[class~='focus'] .getUiSvgContainer__SvgContainer-sc-3c9612d7-0 path,.dNOoIw:focus .getUiSvgContainer__SvgContainer-sc-3c9612d7-0 path{fill:rgb(0,120,130);}/*!sc*/
# .dNOoIw[class~='active'],.dNOoIw:active{color:rgb(59,65,68);background-color:rgb(232,233,234);border-color:transparent;box-shadow:none;}/*!sc*/
# .dNOoIw[class~='active'] .getUiSvgContainer__SvgContainer-sc-3c9612d7-0 path,.dNOoIw:active .getUiSvgContainer__SvgContainer-sc-3c9612d7-0 path{fill:rgb(59,65,68);}/*!sc*/
# .dNOoIw[disabled]{color:rgb(205,209,212);background-color:rgb(245,246,247);border-color:rgb(205,209,212);box-shadow:none;}/*!sc*/
# .dNOoIw[disabled] .getUiSvgContainer__SvgContainer-sc-3c9612d7-0 path{fill:rgb(205,209,212);}/*!sc*/
# data-styled.g64[id="GlobalNavigationButton-sc-52c32037-0"]{content:"dNOoIw,"}/*!sc*/
# .hHdskm li{display:inline-block;border-style:none;margin-right:2px;}/*!sc*/
# .hHdskm li:last-child{margin:0;}/*!sc*/
# .giARhI li{display:inline-block;border-style:none;margin-right:8px;}/*!sc*/
# .giARhI li:last-child{margin:0;}/*!sc*/
# data-styled.g65[id="List__ListContainer-sc-29d56926-0"]{content:"fXiACU,hHdskm,giARhI,"}/*!sc*/
# .cAxDTz{color:rgb(59,65,68);-webkit-transition:background 0.15s ease-in-out;transition:background 0.15s ease-in-out;position:relative;}/*!sc*/
# .cAxDTz > a,.cAxDTz > span,.cAxDTz > button:not(.Button-sc-7eadec1-0){cursor:pointer;padding:8px 16px 8px 16px;color:rgb(59,65,68);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:8px;background-color:transparent;}/*!sc*/
# .cAxDTz > a:focus svg path,.cAxDTz > span:focus svg path,.cAxDTz > button:not(.Button-sc-7eadec1-0):focus svg path{fill:rgb(59,65,68);}/*!sc*/
# .cAxDTz svg{margin-top:-1px;}/*!sc*/
# .cAxDTz > span{cursor:default;}/*!sc*/
# .cAxDTz:hover > a,.cAxDTz:hover > span,.cAxDTz:hover > button:not(.Button-sc-7eadec1-0){color:rgb(255,255,255);background-color:rgb(0,120,130);}/*!sc*/
# .cAxDTz:hover > a svg path,.cAxDTz:hover > span svg path,.cAxDTz:hover > button:not(.Button-sc-7eadec1-0) svg path{fill:rgb(255,255,255);}/*!sc*/
# .cAxDTz:hover > ul{display:block;}/*!sc*/
# .cAxDTz ul{display:none;position:absolute;top:45px;background:rgb(255,255,255);border-radius:4px;box-shadow:0 2px 4px 0 rgba(59,65,68,0.5);padding:4px 0;}/*!sc*/
# .cAxDTz ul a,.cAxDTz ul button{color:rgb(59,65,68);white-space:nowrap;display:block;}/*!sc*/
# .cAxDTz ul a:hover,.cAxDTz ul button:hover{color:rgb(59,65,68);background-color:rgb(232,233,234);}/*!sc*/
# .cAxDTz ul::before{display:block;position:absolute;content:'';width:100%;height:15px;top:-15px;}/*!sc*/
# @media (max-width:62em){.cAxDTz{display:none;}}/*!sc*/
# data-styled.g66[id="sc-1b5f453a-0"]{content:"cAxDTz,"}/*!sc*/
# .bxAcTH{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-left:0;-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;}/*!sc*/
# @media (min-width:1060px){}/*!sc*/
# @media (min-width:1240px){}/*!sc*/
# data-styled.g67[id="sc-cb2f4cac-0"]{content:"bxAcTH,"}/*!sc*/
# .drRhjy{width:16px;height:16px;display:inline-block;border:0px solid rgb(205,209,212);border-width:8px;margin:4px;-webkit-animation:eILmop 0.85s linear infinite;animation:eILmop 0.85s linear infinite;opacity:0.7;}/*!sc*/
# data-styled.g74[id="BusyIndicator-sc-31d65650-0"]{content:"drRhjy,"}/*!sc*/
# .dfEuHz{width:unset;display:inline-block;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;font-weight:bold;border-radius:8px;background-color:rgb(255,255,255);border:none;-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;padding:8px;}/*!sc*/
# .dfEuHz:focus-within{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# data-styled.g75[id="Select__SelectContainer-sc-3c1c6c36-0"]{content:"dfEuHz,"}/*!sc*/
# .ihQZCv{position:absolute;opacity:0;width:100%;height:100%;top:0;left:0;right:0;bottom:0;cursor:pointer;-webkit-appearance:none;font-size:16px;line-height:1.5;}/*!sc*/
# .ihQZCv .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:24px;width:24px;}/*!sc*/
# data-styled.g76[id="Select__NativeSelect-sc-3c1c6c36-1"]{content:"ihQZCv,"}/*!sc*/
# .kFrIlQ{border:1px solid rgb(245,246,247);border-radius:8px;background-color:rgb(245,246,247);color:rgb(59,65,68);font-size:16px;line-height:1.5;width:100%;height:42px;-webkit-transition:width 0.35s ease;transition:width 0.35s ease;padding:8px 48px 8px 16px;-webkit-appearance:none;-moz-appearance:none;appearance:none;outline:none;}/*!sc*/
# .kFrIlQ.react-autosuggest__input--open{border:1px solid rgb(245,246,247);border-radius:8px;}/*!sc*/
# .kFrIlQ .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:24px;width:24px;}/*!sc*/
# .kFrIlQ::-webkit-input-placeholder{color:#606F76;}/*!sc*/
# .kFrIlQ::-moz-placeholder{color:#606F76;}/*!sc*/
# .kFrIlQ:-ms-input-placeholder{color:#606F76;}/*!sc*/
# .kFrIlQ::placeholder{color:#606F76;}/*!sc*/
# .kFrIlQ[placeholder]{text-overflow:ellipsis;}/*!sc*/
# .kFrIlQ::-ms-clear{display:none;}/*!sc*/
# .kFrIlQ::-webkit-search-cancel-button{display:none;}/*!sc*/
# data-styled.g77[id="AutosuggestInput__Input-sc-7f6f4d04-0"]{content:"kFrIlQ,"}/*!sc*/
# .bPSGZd{position:relative;width:100%;}/*!sc*/
# data-styled.g78[id="AutosuggestInput__InputContainer-sc-7f6f4d04-1"]{content:"bPSGZd,"}/*!sc*/
# .fxqEgc{cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:absolute;right:48px;top:0;height:42px;padding:8px;-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;outline:none;}/*!sc*/
# input:not(:focus) + .AutosuggestInput__RightInnerIcon-sc-7f6f4d04-3{pointer-events:none;opacity:0;}/*!sc*/
# input:not(:focus) + .AutosuggestInput__RightInnerIcon-sc-7f6f4d04-3:focus{pointer-events:all;opacity:1;}/*!sc*/
# .fxqEgc:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# data-styled.g80[id="AutosuggestInput__RightInnerIcon-sc-7f6f4d04-3"]{content:"fxqEgc,"}/*!sc*/
# .cDZUnQ{position:absolute;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;right:0;top:0;min-width:42px;cursor:pointer;background-color:rgb(217,60,35);padding:9px 12px;border-bottom-right-radius:8px;border-top-right-radius:8px;-webkit-transition:background-color 0.15s ease;transition:background-color 0.15s ease;}/*!sc*/
# .react-autosuggest__input--open ~ .AutosuggestInput__RightIcon-sc-7f6f4d04-5{border-bottom-right-radius:0;}/*!sc*/
# .cDZUnQ:hover{background-color:rgb(156,17,20);}/*!sc*/
# .cDZUnQ.focus-visible:not(:focus-visible){box-shadow:none;}/*!sc*/
# data-styled.g82[id="AutosuggestInput__RightIcon-sc-7f6f4d04-5"]{content:"cDZUnQ,"}/*!sc*/
# .dCMbJH{position:relative;width:100%;height:100%;-webkit-transition:width 0.35s ease;transition:width 0.35s ease;}/*!sc*/
# .dCMbJH .react-autosuggest__suggestion--first .LocationAutosuggestDrodown__ItemContainer-sc-1bb12592-2{border:none;}/*!sc*/
# .dCMbJH .react-autosuggest__section-title + .react-autosuggest__suggestions-list > .react-autosuggest__suggestion--first .LocationAutosuggestDrodown__ItemContainer-sc-1bb12592-2{border-top:none;}/*!sc*/
# data-styled.g86[id="LocationAutosuggestDrodown__LocationAutosuggestBoxContainer-sc-1bb12592-3"]{content:"dCMbJH,"}/*!sc*/
# .ffxkGC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;border:1px solid rgb(205,209,212);border-bottom-right-radius:8px;border-bottom-left-radius:8px;position:absolute;width:calc(100% + 16px);left:-8px;background:white;-webkit-transition:width 0.35s ease;transition:width 0.35s ease;overflow:hidden;display:none;height:calc(100% - 155px);}/*!sc*/
# @media (min-width:376px){.ffxkGC{height:calc(100% - 108px);}}/*!sc*/
# @media (min-width:570px){.ffxkGC{height:350px;}}/*!sc*/
# @media (min-width:768px){.ffxkGC{height:400px;}}/*!sc*/
# data-styled.g87[id="AutosuggestDropdown__LocationAutosuggestDropdown-sc-d7b5939c-0"]{content:"ffxkGC,"}/*!sc*/
# .fLTqSg{overflow:auto;-webkit-overflow-scrolling:touch;width:100%;max-height:100%;padding-bottom:0;}/*!sc*/
# data-styled.g88[id="AutosuggestDropdown__ScrollContainer-sc-d7b5939c-1"]{content:"fLTqSg,"}/*!sc*/
# .lmZRFz{padding:16px env(safe-area-inset-right) 16px env(safe-area-inset-left);font-size:12px;line-height:1.33;}/*!sc*/
# .lmZRFz .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:15.96px;width:15.96px;}/*!sc*/
# @media (max-width:23.4375em){.lmZRFz{line-height:22px;}}/*!sc*/
# data-styled.g98[id="sc-104ff435-0"]{content:"lmZRFz,"}/*!sc*/
# .cwMtTp{color:rgb(59,65,68);}/*!sc*/
# .cwMtTp:hover{color:rgb(0,120,130);}/*!sc*/
# @media (max-width:23.4375em){.cwMtTp{line-height:25px;}}/*!sc*/
# data-styled.g99[id="sc-bd4acbcf-0"]{content:"cwMtTp,"}/*!sc*/
# .ipmwvr{padding:16px env(safe-area-inset-right) env(safe-area-inset-bottom) env(safe-area-inset-left);font-size:10px;line-height:1.6;}/*!sc*/
# .ipmwvr .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:16px;width:16px;}/*!sc*/
# data-styled.g100[id="sc-5df44c5-0"]{content:"ipmwvr,"}/*!sc*/
# .krJbXC{padding:0;font-size:12px;line-height:1.33;}/*!sc*/
# .krJbXC .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:15.96px;width:15.96px;}/*!sc*/
# data-styled.g101[id="sc-34b01997-0"]{content:"krJbXC,"}/*!sc*/
# .gOdqDU{padding:0 env(safe-area-inset-right) 0 env(safe-area-inset-left);}/*!sc*/
# data-styled.g102[id="sc-18275fd7-0"]{content:"gOdqDU,"}/*!sc*/
# .hqeXdM{color:rgb(59,65,68);-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .hqeXdM:hover{color:rgb(0,120,130);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g103[id="sc-18275fd7-1"]{content:"hqeXdM,"}/*!sc*/
# .gehsuh{list-style:none;display:inline-block;margin:0;padding:16px 0 16px;}/*!sc*/
# .gehsuh li{display:inline;}/*!sc*/
# .gehsuh li + li::before{content:'';display:inline-block;vertical-align:middle;width:4px;height:4px;border-radius:50%;background-color:currentColor;margin:0 4px 2px;}/*!sc*/
# data-styled.g104[id="sc-18275fd7-2"]{content:"gehsuh,"}/*!sc*/
# @media (max-width:47.9375em){.dcLqin{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.dcLqin::after{content:'';width:4px;height:4px;border-radius:50%;background-color:currentColor;margin:0 4px 0;}.dcLqin:last-child:after{display:none;}}/*!sc*/
# @media (max-width:47.9375em){.uykJM{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.uykJM::after{content:'';width:4px;height:4px;border-radius:50%;background-color:currentColor;margin:0 4px 0;}.uykJM:last-child:after{display:none;}}/*!sc*/
# .uykJM:after{display:none;}/*!sc*/
# .jZRNpz{display:none;}/*!sc*/
# data-styled.g105[id="sc-d40e1112-0"]{content:"dcLqin,uykJM,jZRNpz,"}/*!sc*/
# .fnZQhq{color:rgb(59,65,68);-webkit-text-decoration:none;text-decoration:none;padding:2px 0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .fnZQhq:hover{color:rgb(0,120,130);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .fnZQhq div{padding-right:24px;}/*!sc*/
# @media (max-width:23.4375em){.fnZQhq{line-height:25px;}}/*!sc*/
# data-styled.g106[id="sc-d40e1112-1"]{content:"fnZQhq,"}/*!sc*/
# .kKVKHu{padding:32px 0 8px 0;}/*!sc*/
# @media (min-width:48em){.kKVKHu{padding:2px 0;}}/*!sc*/
# .kKVKHu a{color:rgb(59,65,68);-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .kKVKHu a:hover{color:rgb(0,120,130);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g107[id="sc-d40e1112-2"]{content:"kKVKHu,"}/*!sc*/
# .iEJVoJ{position:relative;color:rgb(0,173,187);font-size:12px;line-height:1.33;padding:0;}/*!sc*/
# .iEJVoJ .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:15.96px;width:15.96px;}/*!sc*/
# data-styled.g108[id="sc-d40e1112-3"]{content:"iEJVoJ,"}/*!sc*/
# .ctcJBO{-webkit-flex:1 1 0px;-ms-flex:1 1 0px;flex:1 1 0px;margin-left:8px;}/*!sc*/
# .ctcJBO:first-child{margin-left:0;}/*!sc*/
# @media (max-width:47.9375em){.ctcJBO{-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;margin-left:0;}}/*!sc*/
# data-styled.g109[id="sc-d40e1112-4"]{content:"ctcJBO,"}/*!sc*/
# .eTqHYF{padding:0 env(safe-area-inset-right) 0 env(safe-area-inset-left);}/*!sc*/
# data-styled.g110[id="sc-9ab3dbf-0"]{content:"eTqHYF,"}/*!sc*/
# .kjxHMb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;padding:0 0 24px;}/*!sc*/
# @media (max-width:47.9375em){.kjxHMb{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}}/*!sc*/
# data-styled.g111[id="sc-9ab3dbf-1"]{content:"kjxHMb,"}/*!sc*/
# .jDALtH{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g112[id="sc-5f98f889-0"]{content:"jDALtH,"}/*!sc*/
# .eCqsCF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;height:64px;margin:0;padding:0 16px 0 16px;padding:0 calc(16px + env(safe-area-inset-right)) 0 calc(16px + env(safe-area-inset-left));background-color:rgb(255,255,255);position:relative;z-index:100;font-size:15px;border-bottom:none;}/*!sc*/
# @media (max-width:62em){.eCqsCF{padding:0 12px;}}/*!sc*/
# data-styled.g120[id="sc-a6d0b0a9-0"]{content:"eCqsCF,"}/*!sc*/
# .hxbNXz{margin-left:16px;padding:0 4px;background-color:rgb(255,255,255);}/*!sc*/
# @media (max-width:62em){.hxbNXz{margin-right:-10px;margin-left:2px;}}/*!sc*/
# data-styled.g121[id="sc-a6d0b0a9-1"]{content:"hxbNXz,"}/*!sc*/
# .fWFNxl{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;padding:16px 24px 16px 0;}/*!sc*/
# @media (max-width:62em){.fWFNxl{padding:12px 12px 12px 6px;}}/*!sc*/
# data-styled.g122[id="sc-a6d0b0a9-2"]{content:"fWFNxl,"}/*!sc*/
# .fVmBNf{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;height:100%;}/*!sc*/
# data-styled.g124[id="sc-a6d0b0a9-4"]{content:"fVmBNf,"}/*!sc*/
# .cOnNgG{-webkit-flex:0 1 420px;-ms-flex:0 1 420px;flex:0 1 420px;height:42px;}/*!sc*/
# @media (max-width:62em){.cOnNgG{-webkit-flex:1 1 100%;-ms-flex:1 1 100%;flex:1 1 100%;}}/*!sc*/
# data-styled.g130[id="sc-f992cb56-5"]{content:"cOnNgG,"}/*!sc*/
# @media (max-width:1240px){.jMLcke{display:none;}}/*!sc*/
# @media (max-width:1060px){.jMLcke{display:none;}}/*!sc*/
# data-styled.g131[id="sc-f992cb56-6"]{content:"jMLcke,"}/*!sc*/
# .dRIsUy{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;}/*!sc*/
# @media (max-width:62em){.dRIsUy{display:none;}}/*!sc*/
# data-styled.g133[id="sc-f992cb56-8"]{content:"dRIsUy,"}/*!sc*/
# .gmslVs{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;padding:2px 8px;border-radius:4px;background-color:rgb(232,233,234);cursor:default;}/*!sc*/
# .gmslVs:focus{outline:none;box-shadow:0 0 1px 1px rgb(107,119,128);}/*!sc*/
# data-styled.g155[id="Tag__TagBase-sc-86bd2b12-1"]{content:"gmslVs,"}/*!sc*/
# .byHmsH{padding-top:calc(24px / 4);}/*!sc*/
# data-styled.g161[id="PropertyCard__PropertyCardExtendedContentContainer-sc-1db7e5fa-0"]{content:"byHmsH,"}/*!sc*/
# .gLREdM{text-transform:uppercase;line-height:13px;padding-bottom:4px;}/*!sc*/
# data-styled.g162[id="PropertyCard__CapitalizedText-sc-1db7e5fa-1"]{content:"gLREdM,"}/*!sc*/
# .kqA-dFz{width:100%;border-radius:8px;}/*!sc*/
# .kqA-dFz:hover{cursor:pointer;}/*!sc*/
# data-styled.g163[id="PropertyCard__InteractivePropertyCardContainer-sc-1db7e5fa-2"]{content:"kqA-dFz,"}/*!sc*/
# .iEvuAF{display:block;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# data-styled.g164[id="PropertyCard__StyledLink-sc-1db7e5fa-3"]{content:"iEvuAF,"}/*!sc*/
# .btjSAC{min-width:224px;width:224px;width:100%;height:100%;}/*!sc*/
# .btjSAC a,.btjSAC a:hover{color:inherit;}/*!sc*/
# data-styled.g165[id="PropertyCard__PropertyCardContainer-sc-1db7e5fa-4"]{content:"btjSAC,"}/*!sc*/
# .bfDsir{position:absolute;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;height:100%;}/*!sc*/
# data-styled.g166[id="Tiles__TileBackground-sc-acb4d428-0"]{content:"bfDsir,"}/*!sc*/
# .dqZjAV{background-color:rgb(232,233,234);position:relative;border-radius:8px;overflow:hidden;cursor:pointer;-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;width:100%;height:100%;outline:none;}/*!sc*/
# @media (hover:hover){.dqZjAV{-webkit-mask-image:-webkit-radial-gradient(white,black);}.dqZjAV > .Tiles__TileBackground-sc-acb4d428-0{-webkit-transition:-webkit-transform 0.45s cubic-bezier(0.645,0.045,0.355,1);-webkit-transition:transform 0.45s cubic-bezier(0.645,0.045,0.355,1);transition:transform 0.45s cubic-bezier(0.645,0.045,0.355,1);}.dqZjAV:hover > .Tiles__TileBackground-sc-acb4d428-0{-webkit-transform:scale(1.04);-ms-transform:scale(1.04);transform:scale(1.04);}.dqZjAV:focus-visible{-webkit-mask-image:none;}}/*!sc*/
# .dqZjAV:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# .cpTdvw{background-color:rgb(232,233,234);position:relative;border-radius:8px;overflow:hidden;cursor:pointer;-webkit-transition:box-shadow 0.1s ease,border-color 0.1s ease;transition:box-shadow 0.1s ease,border-color 0.1s ease;width:100%;height:100%;outline:none;}/*!sc*/
# @media (hover:hover){.cpTdvw{-webkit-mask-image:-webkit-radial-gradient(white,black);}.cpTdvw > .Tiles__TileBackground-sc-acb4d428-0{-webkit-transition:-webkit-transform 0.45s cubic-bezier(0.645,0.045,0.355,1);-webkit-transition:transform 0.45s cubic-bezier(0.645,0.045,0.355,1);transition:transform 0.45s cubic-bezier(0.645,0.045,0.355,1);will-change:transform;}.cpTdvw:hover > .Tiles__TileBackground-sc-acb4d428-0{-webkit-transform:scale(1.1);-ms-transform:scale(1.1);transform:scale(1.1);}.cpTdvw:focus-visible{-webkit-mask-image:none;}}/*!sc*/
# .cpTdvw:focus-visible{box-shadow: rgb(255,255,255) 0px 0px 0px 1px, rgb(77,197,207) 0px 0px 2px 3px, rgb(0,120,130) 0px 0px 2px 4px;}/*!sc*/
# data-styled.g167[id="Tiles__TileContainer-sc-acb4d428-1"]{content:"dqZjAV,cpTdvw,"}/*!sc*/
# .bGAnbK{-webkit-flex:1;-ms-flex:1;flex:1;-webkit-order:2;-ms-flex-order:2;order:2;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:100%;font-weight:bold;font-size:28px;line-height:1.14;}/*!sc*/
# .bGAnbK .getUiSvgContainer__SvgContainer-sc-3c9612d7-0{height:31.919999999999998px;width:31.919999999999998px;}/*!sc*/
# data-styled.g170[id="Tiles__TileContent-sc-acb4d428-4"]{content:"bGAnbK,"}/*!sc*/
# ...
#                   <span class="Text__TextBase-sc-27a633b1-0 bOnOwI">
#                    More
#                   </span>
#                  </div>
#                  <div class="getUiSvgContainer__SvgContainer-sc-3c9612d7-0 dMGKtZ">
#                   <svg aria-hidden="true" aria-label="" class="svg" role="img" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg">
#                    <path d="M15.961 18.183l7.056-7.147 1.893 1.868-8.951 9.068-8.927-9.069 1.896-1.866z" fill="#869099">
#                    </path>
#                   </svg>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li class="sc-d40e1112-0 jZRNpz">
#               <a class="sc-d40e1112-1 fnZQhq" href="/for_rent/New_York,NY/CONDO_type/">
#                Condos
#               </a>
#              </li>
#              <li class="sc-d40e1112-0 jZRNpz">
#               <a class="sc-d40e1112-1 fnZQhq" href="/for_rent/New_York,NY/1p_beds/">
#                New York One Bedroom Apartments
#               </a>
#              </li>
#              <li class="sc-d40e1112-0 jZRNpz">
#               <a class="sc-d40e1112-1 fnZQhq" href="/for_rent/New_York,NY/2p_beds/">
#                New York Two Bedroom Apartments
#               </a>
#              </li>
#              <li class="sc-d40e1112-0 jZRNpz">
#               <a class="sc-d40e1112-1 fnZQhq" href="/for_rent/New_York,NY/3p_beds/">
#                New York Three Bedroom Apartments
#               </a>
#              </li>
#              <li class="sc-d40e1112-0 jZRNpz">
#               <a class="sc-d40e1112-1 fnZQhq" href="/for_rent/New_York,NY/4p_beds/">
#                New York Four Bedroom Apartments
#               </a>
#              </li>
#              <li class="sc-d40e1112-0 jZRNpz">
#               <a class="sc-d40e1112-1 fnZQhq" href="/for_rent/New_York,NY/cats,lg_dogs,sm_dogs_pets/">
#                New York Pet Friendly Apartments
#               </a>
#              </li>
#             </ul>
#            </div>
#            <div class="sc-d40e1112-4 ctcJBO">
#             <ul class="List__ListContainer-sc-29d56926-0 fXiACU">
#              <li>
#               <h2 class="sc-d40e1112-2 kKVKHu" style="margin:0 0 8px 0">
#                <div class="Text__TextBase-sc-27a633b1-0-div Text__TextContainerBase-sc-27a633b1-1 cKPFhe gtvmjT">
#                 Real Estate Guides
#                </div>
#               </h2>
#              </li>
#              <li class="sc-d40e1112-0 dcLqin">
#               <a class="sc-d40e1112-1 fnZQhq" href="/NY/">
#                Newest Homes for Sale in New York
#               </a>
#              </li>
#              <li class="sc-d40e1112-0 dcLqin">
#               <a class="sc-d40e1112-1 fnZQhq" href="/for_rent/NY/">
#                Newest Rentals in New York
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#          <div class="Padding-sc-bf66b591-0 fXlXF">
#           <div class="Text__TextBase-sc-27a633b1-0-div Text__TextContainerBase-sc-27a633b1-1 bzzQyw gtvmjT">
#            Trulia is a registered Trademark of Zillow, Inc. Zillow, Inc. holds real estate brokerage
#            <!-- -->
#            <a class="Anchor__StyledAnchor-sc-fead93c0-1 cgbIeG" href="https://www.zillow.com/info/real-estate-licenses" rel="noreferrer noopener nofollow noindex" target="_blank" type="highlight">
#             licenses
#            </a>
#            <!-- -->
#            in all 50 states and D.C. and Zillow (Canada) Inc. holds real estate brokerage
#            <!-- -->
#            <a class="Anchor__StyledAnchor-sc-fead93c0-1 cgbIeG" href="https://www.zillow.com/info/real-estate-licenses" rel="noreferrer noopener nofollow noindex" target="_blank" type="highlight">
#             licenses
#            </a>
#            <!-- -->
#            in multiple provinces.
#           </div>
#           <div class="Text__TextBase-sc-27a633b1-0-div Text__TextContainerBase-sc-27a633b1-1 cKvYni gtvmjT">
#            <a class="Anchor__StyledAnchor-sc-fead93c0-1 cgbIeG" href="https://s.zillow.net/pfs/static/SOP_NYS.pdf" rel="noreferrer noopener nofollow" target="_blank" type="highlight">
#             § 442-H New York Standard Operating Procedures
#            </a>
#            <br/>
#            <a class="Anchor__StyledAnchor-sc-fead93c0-1 cgbIeG" href="https://dos.ny.gov/system/files/documents/2021/08/fairhousingnotice.pdf" rel="noreferrer noopener nofollow" target="_blank" type="highlight">
#             New York Fair Housing Notice
#            </a>
#            <br/>
#            <span class="sc-5f98f889-0 jDALtH">
#             TREC:
#            </span>
#            <a class="Anchor__StyledAnchor-sc-fead93c0-1 cgbIeG" href="https://s.zillow.net/pfs/static/TREC_ZINC_1-25-21.pdf" rel="noreferrer noopener nofollow" target="_blank" type="highlight">
#             Information about brokerage services
#            </a>
#            ,
#            <!-- -->
#            <a class="Anchor__StyledAnchor-sc-fead93c0-1 cgbIeG" href="https://www.trec.texas.gov/forms/consumer-protection-notice" rel="noreferrer noopener nofollow" target="_blank" type="highlight">
#             Consumer protection notice
#            </a>
#            <br/>
#            California DRE #1522444
#           </div>
#           <div class="Text__TextBase-sc-27a633b1-0-div Text__TextContainerBase-sc-27a633b1-1 bzzQyw gtvmjT">
#            <a class="Anchor__StyledAnchor-sc-fead93c0-1 cgbIeG" href="https://www.trulia.com/info/contact-us/" rel="noreferrer noopener" target="_blank" type="highlight">
#             Contact Zillow, Inc Brokerage
#            </a>
#           </div>
#          </div>
#          <div class="sc-18275fd7-0 gOdqDU">
#           <div class="sc-18275fd7-2 gehsuh">
#            <li>
#             Trulia Corporate
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-fead93c0-1 dysGWC sc-bd4acbcf-0 cwMtTp" href="https://www.zillowgroup.com/about-zillow-group/" rel="nofollow" type="highlight">
#              About Zillow Group
#             </a>
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-fead93c0-1 dysGWC sc-bd4acbcf-0 cwMtTp" href="https://www.zillow.com/rental-manager/resources/fair-housing-guide/" rel="nofollow" type="highlight">
#              Fair Housing Guide
#             </a>
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-fead93c0-1 dysGWC sc-bd4acbcf-0 cwMtTp" href="https://www.zillow.com/careers/" rel="nofollow" type="highlight">
#              Careers
#             </a>
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-fead93c0-1 dysGWC sc-bd4acbcf-0 cwMtTp" href="https://www.trulia.com/newsroom/" rel="nofollow" type="highlight">
#              Newsroom
#             </a>
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-fead93c0-1 dysGWC sc-bd4acbcf-0 cwMtTp" href="https://investors.zillowgroup.com/" rel="nofollow" type="highlight">
#              Investor Relations
#             </a>
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-fead93c0-1 dysGWC sc-bd4acbcf-0 cwMtTp" href="https://www.trulia.com/terms/advertisers/" rel="nofollow" type="highlight">
#              Advertising Terms
#             </a>
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-fead93c0-1 dysGWC sc-bd4acbcf-0 cwMtTp" href="https://www.zillowgroup.com/zg-privacy-policy/" rel="nofollow" type="highlight">
#              Privacy
#             </a>
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-fead93c0-1 dysGWC sc-bd4acbcf-0 cwMtTp" href="https://www.trulia.com/info/terms/" rel="nofollow" type="highlight">
#              Terms of Use
#             </a>
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-fead93c0-1 dysGWC sc-bd4acbcf-0 cwMtTp" href="https://www.trulia.com/info/listings-quality-policy/" rel="nofollow" type="highlight">
#              Listings Quality Policy
#             </a>
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-fead93c0-1 dysGWC sc-bd4acbcf-0 cwMtTp" href="https://www.zillow.com/corp/SATerms.htm" rel="nofollow" type="highlight">
#              Subscription Terms
#             </a>
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-fead93c0-1 dysGWC sc-bd4acbcf-0 cwMtTp" href="https://support.trulia.com/hc/en-us" type="highlight">
#              Help
#             </a>
#            </li>
#            <li>
#             <a class="Anchor__StyledAnchor-sc-fead93c0-1 dysGWC sc-bd4acbcf-0 cwMtTp" href="https://privacy.zillowgroup.com/" rel="nofollow" type="highlight">
#              Privacy Portal
#             </a>
#            </li>
#            <li>
#             <div aria-label="Cookie Preference" class="Box__BoxElement-sc-9529e829-0 bjkomQ BoxButton-sc-155631a2-0 cpuvdb UiButton-sc-457c87e0-0 hbfUXF sc-18275fd7-1 hqeXdM optanon-toggle-display" role="button" tabindex="0">
#              Cookie Preference
#             </div>
#            </li>
#            <li>
#             <a aria-label="Do Not Sell or Share My Personal Information" class="Anchor__StyledAnchor-sc-fead93c0-1 dysGWC" href="https://privacy.zillowgroup.com/cookie" rel="nofollow" style="display:inline-block;vertical-align:middle" target="_blank" type="highlight">
#              <div class="Text__TextBase-sc-27a633b1-0-div Text__TextContainerBase-sc-27a633b1-1 bzzQyw gtvmjT">
#               <div class="MediaBlock__MediaContainer-sc-ad2f5bfc-0 caedLv">
#                <div class="MediaBlock__MediaContent-sc-ad2f5bfc-1 jTGvwb">
#                 Do Not Sell or Share My Personal Information
#                </div>
#                <div class="getUiSvgContainer__SvgContainer-sc-3c9612d7-0 gZZJMh">
#                 <svg aria-hidden="true" aria-label="" class="svg" role="img" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg">
#                  <path d="M22.756 14.71l-5.11-5.775 1.993-1.762 7.725 8.73-7.693 9.005-2.022-1.728 4.963-5.81H5.56v-2.66h17.195z" fill="#869099">
#                  </path>
#                 </svg>
#                </div>
#               </div>
#              </div>
#             </a>
#            </li>
#           </div>
#          </div>
#          <div class="sc-104ff435-0 lmZRFz">
#           Zillow Group is committed to ensuring digital accessibility for individuals with disabilities.  We are continuously working to improve the accessibility of our web experience for everyone,  and we welcome feedback and accommodation requests. If you wish to report an issue or seek an  accommodation, please
#           <a class="Anchor__StyledAnchor-sc-fead93c0-1 cgbIeG" href="https://support.trulia.com/hc/en-us/requests/new?ticket_form_id=360000050828" rel="nofollow" type="highlight">
#            let us know
#           </a>
#           .
#          </div>
#          <div class="sc-5df44c5-0 ipmwvr">
#           Copyright ©
#           <!-- -->
#           2023
#           <!-- -->
#           Trulia, LLC. All rights reserved.
#           <a class="Anchor__StyledAnchor-sc-fead93c0-1 cgbIeG sc-bd4acbcf-0 cwMtTp" href="https://www.hud.gov/program_offices/fair_housing_equal_opp" rel="nofollow" type="highlight">
#            Equal Housing Opportunity.
#           </a>
#           <span>
#            Have a Question? Visit our
#           </span>
#           <a class="Anchor__StyledAnchor-sc-fead93c0-1 cgbIeG sc-bd4acbcf-0 cwMtTp" href="https://www.trulia.com/help/" rel="nofollow" type="highlight">
#            Help Center
#           </a>
#           to find the answer.
#          </div>
#         </footer>
#        </div>
#       </div>
#       <section aria-label="Interactive Google Map showing listings in New York, NY. Details about each listing, including address and price, can be found in the search results under the h2 heading." class="sc-70dbb0c3-3 cCEOxo" role="region">
#       </section>
#       <span aria-live="assertive" class="ScreenReaderContent-sc-b23e9556-0 jUuqmF">
#       </span>
#      </div>
#     </div>
#    </div>
#    <div style="display:none">
#    </div>
#   </div>
#   <script id="__NEXT_DATA__" type="application/json">
#    {"props":{"abExperiments":{"1274":"control","1316":"b","1317":"_control","1329":"_control","1334":"b","1337":"b","1338":"_control","1341":"b","1353":"b","1357":"b","1365":"b","1371":"b","1375":"b","1377":"b","1379":"b","1380":"b","1386":"b","1393":"b","1394":"b","1395":"b","1401":"b","1406":"b","1408":"a","1409":"b","1416":"c","1418":"b","1419":"a","1421":"a","1428":"control"},"session":{"isBot":false,"id":"session-70ae34f2-4b11-402c-8943-e6f20b6018f4","userLifetimeId":"230509rudng64h9ku1ecxdg142wsm844","transactionId":"74acd343-ca12-42f5-a34b-4c3d0682c39e","supportedMediaTypes":[],"isNonPersonalized":false,"gqlCacheControl":null,"navigatedFrom":false},"abTracking":"1274_control;1316b;1317_control;1329_control;1334b;1337b;1338_control;1341b;1353b;1357b;1365b;1371b;1375b;1377b;1379b;1380b;1386b;1393b;1394b;1395b;1401b;1406b;1408a;1409b;1416c;1418b;1419a;1421a;1428_control","ab":"{\"1274\":\"control\",\"1316\":\"b\",\"1317\":\"_control\",\"1329\":\"_control\",\"1334\":\"b\",\"1337\":\"b\",\"1338\":\"_control\",\"1341\":\"b\",\"1353\":\"b\",\"1357\":\"b\",\"1365\":\"b\",\"1371\":\"b\",\"1375\":\"b\",\"1377\":\"b\",\"1379\":\"b\",\"1380\":\"b\",\"1386\":\"b\",\"1393\":\"b\",\"1394\":\"b\",\"1395\":\"b\",\"1401\":\"b\",\"1406\":\"b\",\"1408\":\"a\",\"1409\":\"b\",\"1416\":\"c\",\"1418\":\"b\",\"1419\":\"a\",\"1421\":\"a\",\"1428\":\"control\"}","htmlBodyClassNames":[],"cloudFrontRequestId":"BVyB8OKAOHnPtQd-bE5MmRYjezi2uDvB-Uewlw44h2BNiX0Qq-QE1Q==","isAdvertisingCookieBlocked":false,"_page":{"title":"Apartments For Rent in New York, NY - 13,362 Long Term Rentals | Trulia","description":"Search 13,362 Rental Properties in New York, New York. Explore rentals by neighborhoods, schools, local guides and more on Trulia!","metaTags":{"robots":{"name":"robots","content":"INDEX, FOLLOW"},"ogUrl":{"property":"og:url","content":"https://www.trulia.com/for_rent/New_York,NY/"},"ogDescription":{"property":"og:description","content":"Search 13,362 Rental Properties in New York, New York. Explore rentals by neighborhoods, schools, local guides and more on Trulia!"},"ogTitle":{"property":"og:title","content":"Apartments For Rent in New York, NY - 13,362 Long Term Rentals | Trulia"},"ogImage":{"property":"og:image","content":"https://www.trulia.com/images/logos/standardized/v4/logo-with-icon-200x200.png"},"ogImageWidth":{"property":"og:image:width","content":"200"},"ogImageHeight":{"property":"og:image:height","content":"200"}},"linkTags":{"heroImgPreload":{"rel":"preload","as":"image","href":"https://www.trulia.com/pictures/thumbs_4/zillowstatic/fp/00ca20c0f040f67e66bfc6738275e5fa-full.jpg"},"mapBgImgPreload":{"rel":"preload","as":"image","href":"https://www.trulia.com/images/backgrounds/map-gray-background.png"},"androidDeeplink":{"rel":"alternate","href":"android-app://com.trulia.android/https/www.trulia.com/for_rent/New_York,NY/"},"iosDeeplink":{"rel":"alternate","href":"ios-app://288487321/https/www.trulia.com/for_rent/New_York,NY/"},"canonicalUrl":{"rel":"canonical","href":"https://www.trulia.com/for_rent/New_York,NY/"}},"branchBanner":{"bannerOptions":{"disable_entry_animation":true,"metadata":{"banner":true,"bottomBanner":false,"page":"srp","pageType":"for-rent-srp"}},"bannerViewData":{"data":{"city":"New York","state":"NY","county":null,"neighborhood":null,"zipCode":null}}},"ads":{"pageType":"trulia_srp"},"viewer":{"userStatus":null,"userType":null,"userId":null,"loggedIn":null,"name":null,"email":null,"profileImage":null,"permissions":null,"userNavigation":null,"optedOutOfSale":false,"__typename":"USER_Viewer"}},"appProps":{"abExperiments":{"1274":"control","1316":"b","1317":"_control","1329":"_control","1334":"b","1337":"b","1338":"_control","1341":"b","1353":"b","1357":"b","1365":"b","1371":"b","1375":"b","1377":"b","1379":"b","1380":"b","1386":"b","1393":"b","1394":"b","1395":"b","1401":"b","1406":"b","1408":"a","1409":"b","1416":"c","1418":"b","1419":"a","1421":"a","1428":"control"},"session":{"isBot":false,"id":"session-70ae34f2-4b ...
#   </script>
#  </body>
# </html>

# %%
# Find a tag
soup.find("span")
# Out:
# <span class="Text__TextBase-sc-27a633b1-0 cVaxpe">New York</span>

# %%
# Find all span tags
spans = soup.findAll("span")

# %%
# This is equivalent to a list
type(spans)
# Out:
# bs4.element.ResultSet

# %%
# First element of the list
spans[0]
# Out:
# <span class="Text__TextBase-sc-27a633b1-0 cVaxpe">New York</span>

# %%
# Find all property prices
prices = soup.findAll("div",attrs = {"data-testid":"property-price"})

# %%
# Get all prices
clean_p = [p.text for p in prices]
clean_p
# Out:
# ['$4,200/mo',
#  '$3,445 - $7,445/mo',
#  '$3,577 - $7,005/mo',
#  '$3,112 - $4,451/mo',
#  '$2,441 - $3,699/mo',
#  '$4,304 - $7,894/mo',
#  '$4,562/mo']

# %%
# Extract low and high prices
low_prices = []
high_prices = []
for p in clean_p:
    if "-" in p: # If the price is a range
        low_price, high_price = p.split("-")
        low_prices.append(float(low_price.replace(",", "").replace("$", "").replace("/mo", "")))
        high_prices.append(float(high_price.replace(",", "").replace("$", "").replace("/mo", "")))
    else: # If the price is not a range
        low_prices.append(float(p.replace(",", "").replace("$", "").replace("/mo", "")))
        high_prices.append(float(p.replace(",", "").replace("$", "").replace("/mo", "")))
        
# Print low and high prices
print("Low prices: ", low_prices)
print("High prices: ", high_prices)
# Out:
# Low prices:  [4200.0, 3445.0, 3577.0, 3112.0, 2441.0, 4304.0, 4562.0]
# High prices:  [4200.0, 7445.0, 7005.0, 4451.0, 3699.0, 7894.0, 4562.0]

# %% [markdown]
# # I  Web scrapped Appartments.com to find out the cost of renting apartments in New York

# %%
# We talk about user agents later so run and ignore
user_agent_list = ["Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246" 
,"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.111 Safari/537.36 "
,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9 "
,"Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:15.0) Gecko/20100101 Firefox/15.0.1" 
,"Mozilla/5.0 (X11; CrOS x86_64 8172.45.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.64 Safari/537.36"] 

headers = {
    'User-Agent': user_agent_list[3]}

# %%
# Do your Request
URL = "https://www.apartments.com/new-york-ny/?bb=uz_842s_vHkt_2lkC"
page = requests.get(URL, headers = headers)

# %%
# Response of request object
print(page)
# Out:
# <Response [200]>

# %%
page = requests.get(URL, headers = headers)

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
pricing = soup.find("p", {"class": "property-pricing"})

# %%
# extract the low and high prices
low_price = float(pricing.text.split(" - ")[0].replace(",", "").replace("$", ""))
high_price = float(pricing.text.split(" - ")[1].replace(",", "").replace("$", ""))

# %%
# initialize empty lists for low and high prices
low_prices = []
high_prices = []

# loop through each pricing element
for pricing in pricing_list:
    # extract the low and high prices
    price_parts = pricing.text.split(" - ")
    if len(price_parts) == 2:
        low_price = float(price_parts[0].replace(",", "").replace("$", ""))
        high_price = float(price_parts[1].replace(",", "").replace("$", ""))
    elif len(price_parts) == 1 and price_parts[0] != "Call for Rent":
        # if there is only one price and it's not "Call for Rent", use it as both the low and high prices
        low_price = high_price = float(price_parts[0].replace(",", "").replace("$", ""))
    else:
        # if the price is "Call for Rent" or empty, set the low and high prices to None
        low_price = high_price = None
    
    # append the low and high prices to their respective lists
    low_prices.append(low_price)
    high_prices.append(high_price)

# create a list of tuples from low_prices and high_prices
#price_list = list(zip(low_prices, high_prices))

# print the list of prices
print(low_prices)
# Out:
# [3375.0, 4070.0, 4675.0, 3995.0, 3750.0, 4295.0, 3000.0, 5923.0, 3580.0, 3330.0, 2955.0, 3900.0, 4885.0, 1283.0, 3869.0, 4950.0, 4029.0, 4600.0, 3675.0, 3800.0, None, 3460.0, 3733.0, 4500.0, 2275.0]

# %%
import pandas as pd

# initialize empty lists for low and high prices
low_prices = []
high_prices = []

# loop through each pricing element
for pricing in pricing_list:
    # extract the low and high prices
    price_parts = pricing.text.split(" - ")
    if len(price_parts) == 2:
        low_price = float(price_parts[0].replace(",", "").replace("$", ""))
        high_price = float(price_parts[1].replace(",", "").replace("$", ""))
        # append the low and high prices to their respective lists
        low_prices.append(low_price)
        high_prices.append(high_price)

# %%
print( low_prices)
# Out:
# [3375.0, 4070.0, 4675.0, 3995.0, 3750.0, 4295.0, 3000.0, 3580.0, 3330.0, 2955.0, 3900.0, 4885.0, 1283.0, 3869.0, 4029.0, 3675.0, 3800.0, 3460.0, 3733.0, 4500.0]

# %%
len(low_prices)
# Out:
# 20

# %%
# find all the span elements with class "js-placardTitle title" on the page
title_list = soup.find_all("span", {"class": "js-placardTitle title"})

# initialize an empty list for the titles
titles = []

# loop through each title element
for title in title_list:
    # append the text content of the title element to the list of titles
    titles.append(title.text)

# print the list of titles
print( titles)
# Out:
# ['Lyra', 'EOS', 'Park Towers South', 'VIA 57 WEST', 'The Helena', '70 W 45th St', 'The Smile Residential', 'FRANK 57 WEST', 'View 34', 'Lincoln at Bankside', 'Third at Bankside', 'Yorkshire Towers', '15 W 55th St', 'The Heritage by Common', '535 W 43rd Street', '510 West End Avenue', 'The Buchanan', '605 W 112th St', '792 Columbus Avenue', 'Manhattan Park', '120 West 97th  Street', 'Marquis Apartments', 'The Landon', 'Pod Pads', 'Riverton Square']

# %%
# find all the div elements with class "property-address" and extract their text content
address_list = [address.text.strip() for address in soup.find_all('div', {'class': 'property-address js-url'})]

# print the list of addresses
print(address_list)
# Out:
# ['555 W 38th St, New York, NY 10018', '100 W 31st St, New York, NY 10001', '315 W 57th St, New York, NY 10019', '625 W 57th St, New York, NY 10019', '601 W 57th St, New York, NY 10019', '70 W 45th St, New York, NY 10036', '158 E 126th St, New York, NY 10035', '600 W 58th St, New York, NY 10019', '401 E 34th St, New York, NY 10016', '101 Lincoln Ave, Bronx, NY 10454', '2401 3rd Ave, Bronx, NY 10451', '305-315 E 86th St, New York, NY 10028', '15 W 55th St, New York, NY 10019', '1295 5th Ave, New York, NY 10029', '546 W 44th St, New York, NY 10036', '510 West End Ave, New York, NY 10024', '160 E 48th St, New York, NY 10017', 'New York, NY 10025', '784-792 Columbus Ave, New York, NY 10025', '10-40 River Rd, New York, NY 10044', '755 Amsterdam Ave, New York, NY 10025', '150 E 34th St, New York, NY 10016', '520 W 43rd St, New York, NY 10036', '400 W 42nd St, New York, NY 10036', '2225-2265 5th Ave, New York, NY 10037']

# %%
beds_list = [address.text.strip() for address in soup.find_all('p', {'class': 'property-beds'})]

print(beds_list)
# Out:
# ['Studio - 2 Beds', 'Studio - 2 Beds', 'Studio - 1 Bed', 'Studio - 3 Beds', 'Studio - 1 Bed', '1-3 Beds', 'Studio - 2 Beds', '3 Beds', 'Studio - 3 Beds', 'Studio - 3 Beds', 'Studio - 3 Beds', 'Studio - 3 Beds', '2-3 Beds', 'Studio', 'Studio - 2 Beds', '2 Beds', 'Studio - 3 Beds', '1 Bed', 'Studio - 2 Beds', '1-2 Beds', 'Studio - 3 Beds', 'Studio - 1 Bed', 'Studio - 2 Beds', '1-2 Beds', '1-3 Beds']

# %%
# create DataFrame from low_prices and high_prices lists
df = pd.DataFrame({
    'Low Prices': low_prices,
    'High Prices': high_prices,
    "Titles": titles,
    'Address': address_list,
    'Beds':beds_list,
    
})

# print the DataFrame
df
# Out:
#     Low Prices  High Prices                  Titles  \
# 0       3375.0       5250.0                    Lyra
# 1       4070.0       7921.0                     EOS
# 2       4675.0       8600.0       Park Towers South
# 3       3995.0      11995.0             VIA 57 WEST
# 4       3750.0       4250.0              The Helena
# 5       4295.0       8553.0            70 W 45th St
# 6       3000.0       5500.0   The Smile Residential
# 7       5923.0       5923.0           FRANK 57 WEST
# 8       3580.0       8830.0                 View 34
# 9       3330.0       6875.0     Lincoln at Bankside
# 10      2955.0       6370.0       Third at Bankside
# 11      3900.0      14000.0        Yorkshire Towers
# 12      4885.0       7607.0            15 W 55th St
# 13      1283.0       1496.0  The Heritage by Common
# 14      3869.0       7188.0       535 W 43rd Street
# 15      4950.0       4950.0     510 West End Avenue
# 16      4029.0       8681.0            The Buchanan
# 17      4600.0       4600.0          605 W 112th St
# 18      3675.0       8067.0     792 Columbus Avenue
# 19      3800.0       4900.0          Manhattan Park
# 20         NaN          NaN   120 West 97th  Street
# 21      3460.0       4745.0      Marquis Apartments
# 22      3733.0       6371.0              The Landon
# 23      4500.0       9000.0                Pod Pads
# 24      2275.0       2275.0         Riverton Square
#
#                                      Address             Beds
# 0          555 W 38th St, New York, NY 10018  Studio - 2 Beds
# 1          100 W 31st St, New York, NY 10001  Studio - 2 Beds
# 2          315 W 57th St, New York, NY 10019   Studio - 1 Bed
# 3          625 W 57th St, New York, NY 10019  Studio - 3 Beds
# 4          601 W 57th St, New York, NY 10019   Studio - 1 Bed
# 5           70 W 45th St, New York, NY 10036         1-3 Beds
# 6         158 E 126th St, New York, NY 10035  Studio - 2 Beds
# 7          600 W 58th St, New York, NY 10019           3 Beds
# 8          401 E 34th St, New York, NY 10016  Studio - 3 Beds
# 9           101 Lincoln Ave, Bronx, NY 10454  Studio - 3 Beds
# 10             2401 3rd Ave, Bronx, NY 10451  Studio - 3 Beds
# 11     305-315 E 86th St, New York, NY 10028  Studio - 3 Beds
# 12          15 W 55th St, New York, NY 10019         2-3 Beds
# 13          1295 5th Ave, New York, NY 10029           Studio
# 14         546 W 44th St, New York, NY 10036  Studio - 2 Beds
# 15      510 West End Ave, New York, NY 10024           2 Beds
# 16         160 E 48th St, New York, NY 10017  Studio - 3 Beds
# 17                        New York, NY 10025            1 Bed
# 18  784-792 Columbus Ave, New York, NY 10025  Studio - 2 Beds
# 19        10-40 River Rd, New York, NY 10044         1-2 Beds
# 20     755 Amsterdam Ave, New York, NY 10025  Studio - 3 Beds
# 21         150 E 34th St, New York, NY 10016   Studio - 1 Bed
# 22         520 W 43rd St, New York, NY 10036  Studio - 2 Beds
# 23         400 W 42nd St, New York, NY 10036         1-2 Beds
# 24     2225-2265 5th Ave, New York, NY 10037         1-3 Beds
